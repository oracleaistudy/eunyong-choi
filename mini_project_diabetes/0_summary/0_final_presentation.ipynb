# %% [markdown]
# ### 데이터 전처리에 따른 model 성능비교

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# | Model               | Original | Mean   | Median | Nozero |
# | ------------------- | -------- | ------ | ------ | ------ |
# | Logistic Regression | 0.7143   | 0.7013 | 0.7078 | 0.7794 |
# | KNN (k=30)          | 0.7468   | 0.7468 | 0.7532 | 0.7500 |
# | SVM (RBF)           | 0.7403   | 0.7403 | 0.7337 | 0.7941 |
# | Decision Tree       | 0.7273   | 0.6948 | 0.7273 | 0.7353 |
# | Random Forest       | 0.7338   | 0.7273 | 0.7597 | 0.8382 |
# | Gradient Boosting   | 0.7532   | 0.7532 | 0.7597 | 0.8088 |

# %% [markdown]
# ### Nozero data set에서 model 성능 비교

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# | Model               | w/oAge | w/oBloodPressure | w/oBMI | w/oDPF | w/oGlucose | w/oInsulin | w/oPregnancies | w/oSkinThickness | w/oSkinandAge |
# | ------------------- | ------ | ---------------- | ------ | ------ | ---------- | ---------- | -------------- | ---------------- | ------------- |
# | Logistic Regression | 0.7941 | 0.75             | 0.7794 | 0.7647 | 0.6470     | 0.7941     | 0.7941         | 0.7794           | 0.8088        |
# | KNN (k=20)          | 0.7647 | 0.75             | 0.7058 | 0.7205 | 0.6911     | 0.7352     | 0.7941         | 0.7352           | 0.75          |
# | SVM (RBF)           | 0.7941 | 0.7794           | 0.8088 | 0.7941 | 0.6911     | 0.8382     | 0.8088         | 0.7794           | 0.7941        |
# | Decision Tree       | 0.8235 | 0.7352           | 0.7647 | 0.7647 | 0.7058     | 0.8235     | 0.7647         | 0.7647           | 0.8382        |
# | Random Forest       | 0.8088 | 0.7941           | 0.8088 | 0.8235 | 0.7058     | 0.8088     | 0.8676         | 0.7794           | 0.8088        |
# | Gradient Boosting   | 0.8235 | 0.8088           | 0.8088 | 0.7794 | 0.6911     | 0.8235     | 0.8088         | 0.8235           | 0.7941        |
