# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 필터(가중치 도장)이 옆으로 한칸씩 이동하며 합성곱 수행
# - 특성맵: 합성곱의 계산을 통해 얻은 출력
# - 필터(뉴런개수)(커널: 가중치): 가중치 도장
# - 패딩: 입력 배열 주위를 가상의 원소로 채우는 것
# - 세임패딩: 입력 주위에 0으로 패딩
# - 밸리드패딩: 패딩없이 순수한 입력 배열에서만 합성곱을 하여 특성 맵 만드는 경우

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 풀링: 합성곱 층에서 만든 특성 맵의 가로세로 크기를 줄이는 역할, (2,2,3) ->(1,1,3) , 특성맵의 개수는 줄지 않음!!
# - 최대풀링: 도장에서 가장 큰값
# - 평균풀링: 도장 찍은 값의 평균

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 합성곱 신경망의 전체 구조
#
# [합성곱층_세임패딩]
# 1. 합성곱 층에서 사용할 커널의 크기는(도장의 크기) (3,3)이고 세임 패딩(남는 칸 0으로 채움)이므로 1픽셀이 입력 데이터 주변에 추가
# 2. 합성곱의 필터는 3개, 각각 (3,3) 크기의 가중치를 가지고 있음, 필터마다 절편 b를 가지고 있음(도장 손잡이)
# 3. 출력되는 특성 맵의 크기는 입력과 동일한 (4,4)
# 4. 3개의 필터가 하나씩 합성곱의 출력을 만들어 (4,4,3) 크기의 특성 맵 생성
# 5. 활성화 함수 = 렐루 적용
#
# [플링층]
# 1. 보통 (2,2) 풀링을 사용해 절반으로 줄임
# 2. 특성 맵의 개수는 변하지 않음으로 (4,4,3)은 (2,2,3)으로 변환, 특성맵의 개수는 유지
#
# [밀집층]
# 1. 3차원 배열을 1차원으로 펼침, 12개의 원소를 가진 1차원 배열이고 출력층의 입력이 됨

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 첫번째 합성곱의 필터개수(도장개수)가 5개
# - 필터의 너비와 높이가 각각 3이면 필터(도장)의 커널 크기는 (3,3,5) -> 이 합성곱의 결과는 1개 출력을 만듬
# - 도장의 개수가 10개면 만들어진 특성 맵의 크기는 (2,2,10), 뒤에 층이 필터의 개수
# - 합성곱 신경망의 특증 : 너비와 높이는 점점 줄어들고 깊이가 깊어짐
