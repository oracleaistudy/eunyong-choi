# %% [markdown]
# # 텍스트를 위한 인공 신경망
#
# #### 순차데이터
# * 순차데이터(sequential data): 텍스트나 시계열데이터와 같이 순서에 의미가 있는 데이터
# * 피드포워드 신경망(feedforward neural network, FFNN): 입력 데이터의 흐름이 앞으로만 전달되는 신경망 ex)완전 연결 신경망, 합성곱 신경망
#
# ![image.png](attachment:image.png)
#
# * 순환신경망(recurrent neural network, RNN) : 완전 연결 신경망과 비슷, 이전 데이터 처리 결과가 순환되는 고리 추가
#
# ![image-2.png](attachment:image-2.png)
#
# * 타임스텝: 어떤 샘플을 처리할때 그 이전에 사용했던 데이터를 재사용하는 단계
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
# * 순환신경망에는 특별히 층을 셀(cell)이라고 부름, 셀의 출력을 은닉층(hidden state)라고 부름
#
# ![image-6.png](attachment:image-6.png)
#
# * 입력에 어떤 가중치를 곱하고 활설화 함수를 통과시켜 다음 층으로 보냄. 순환신경망은 층의 출력(은닉상태)을 다음 타임스텝에 재사용
# * 일반적으로 은닉층의 활성화 함수로는 hyperbolic tangent 함수인 tanh가 많이 사용, 범위는 -1~1 (시그모이드는 0~1)
#
# ![image-7.png](attachment:image-7.png)
#
# * 순환신경망을 타임스텝마다 그릴 수 있음 = 타임스텝으로 펼침
#
# ![image-8.png](attachment:image-8.png)
#
#
# #### 셀의 가중치와 입출력
# * 입력층과 순환층의 가중치 Wx의 크기는 (4*3) 12개, 은닉상태 가중치 Wh는 (3*3) 9개
#
# ![image-9.png](attachment:image-9.png)
#
# * 모델 파라미터 수 = Wx + Wb+ 절편 = 12 + 9 + 3 = 24
